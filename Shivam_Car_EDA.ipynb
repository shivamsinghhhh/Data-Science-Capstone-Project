# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('CAR DETAILS.csv')
df.head(20)
# Out:
#                                name  year  selling_price  km_driven    fuel
# 0                     Maruti 800 AC  2007          60000      70000  Petrol  \
# 1          Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2              Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3            Datsun RediGO T Option  2017         250000      46000  Petrol
# 4             Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
# 5              Maruti Alto LX BSIII  2007         140000     125000  Petrol
# 6         Hyundai Xcent 1.2 Kappa S  2016         550000      25000  Petrol
# 7          Tata Indigo Grand Petrol  2014         240000      60000  Petrol
# 8          Hyundai Creta 1.6 VTVT S  2015         850000      25000  Petrol
# 9          Maruti Celerio Green VXI  2017         365000      78000     CNG
# 10          Chevrolet Sail 1.2 Base  2015         260000      35000  Petrol
# ...

# %%
df.shape
# Out:
# (4340, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
# View the shape and info of the dataset
row, col = df.shape
print('Row = ', row, 'Col = ', col)

df.info()
# Out:
# Row =  4340 Col =  8
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
# Split the column name to get the model of the car
df["model"] = df.name.apply(lambda x : ' '.join(x.split(' ')[:1]))
df['model'].value_counts()
# Out:
# model
# Maruti           1280
# Hyundai           821
# Mahindra          365
# Tata              361
# Honda             252
# Ford              238
# Toyota            206
# Chevrolet         188
# Renault           146
# Volkswagen        107
# Skoda              68
# Nissan             64
# Audi               60
# BMW                39
# Fiat               37
# Datsun             37
# Mercedes-Benz      35
# Jaguar              6
# Mitsubishi          6
# Land                5
# Volvo               4
# Ambassador          4
# Jeep                3
# MG                  2
# OpelCorsa           2
# Daewoo              1
# Force               1
# Isuzu               1
# Kia                 1
# Name: count, dtype: int64

# %% [markdown]
# # Checking And Handling the null value and duplicates

# %%
# Check null values in dataset
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# model            0
# dtype: int64

# %%
# Check duplicated row in dataset
df[df.duplicated()]
# Out:
#                                  name  year  selling_price  km_driven    fuel
# 13                      Maruti 800 AC  2007          60000      70000  Petrol  \
# 14           Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 15               Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 16             Datsun RediGO T Option  2017         250000      46000  Petrol
# 17              Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
# ...                               ...   ...            ...        ...     ...
# 4307                 Mahindra Xylo H4  2019         599000      15000  Diesel
# 4308              Maruti Alto 800 LXI  2018         200000      35000  Petrol
# 4309                 Datsun GO Plus T  2017         350000      10171  Petrol
# 4310  Renault Duster 110PS Diesel RxL  2015         465000      41123  Diesel
# 4311          Toyota Camry Hybrid 2.5  2017        1900000      20118  Petrol
#
# ...

# %%
# Drop all duplicated row
df = df.drop_duplicates()

df.shape
# Out:
# (3577, 9)

# %%
# View unique values from categorical features
categorical = [col for col in df.columns if df[col].dtypes == 'O']

for col in categorical:
  print(df[col].unique())
# Out:
# ['Maruti 800 AC' 'Maruti Wagon R LXI Minor' 'Hyundai Verna 1.6 SX' ...
#  'Mahindra Verito 1.5 D6 BSIII'
#  'Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV'
#  'Hyundai i20 Magna 1.4 CRDi']
# ['Petrol' 'Diesel' 'CNG' 'LPG' 'Electric']
# ['Individual' 'Dealer' 'Trustmark Dealer']
# ['Manual' 'Automatic']
# ['First Owner' 'Second Owner' 'Fourth & Above Owner' 'Third Owner'
#  'Test Drive Car']
# ['Maruti' 'Hyundai' 'Datsun' 'Honda' 'Tata' 'Chevrolet' 'Toyota' 'Jaguar'
#  'Mercedes-Benz' 'Audi' 'Skoda' 'Jeep' 'BMW' 'Mahindra' 'Ford' 'Nissan'
#  'Renault' 'Fiat' 'Volkswagen' 'Volvo' 'Mitsubishi' 'Land' 'Daewoo' 'MG'
#  'Force' 'Isuzu' 'OpelCorsa' 'Ambassador' 'Kia']

# %%
# Summary of the data set
df.describe()
# Out:
#               year  selling_price      km_driven
# count  3577.000000   3.577000e+03    3577.000000
# mean   2012.962538   4.739125e+05   69250.545709
# std       4.251759   5.093018e+05   47579.940016
# min    1992.000000   2.000000e+04       1.000000
# 25%    2010.000000   2.000000e+05   36000.000000
# 50%    2013.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %% [markdown]
# ##  Exploratory Data Analysis

# %%
car = df.copy()

# %% [markdown]
# # Model Distribution

# %%
car["model"].value_counts().index
# Out:
# Index(['Maruti', 'Hyundai', 'Mahindra', 'Tata', 'Ford', 'Honda', 'Toyota',
#        'Chevrolet', 'Renault', 'Volkswagen', 'Nissan', 'Skoda', 'Fiat', 'Audi',
#        'Datsun', 'BMW', 'Mercedes-Benz', 'Jaguar', 'Mitsubishi', 'Land',
#        'Volvo', 'Jeep', 'Ambassador', 'MG', 'OpelCorsa', 'Daewoo', 'Force',
#        'Isuzu', 'Kia'],
#       dtype='object', name='model')

# %%
def percent(ax):
    heightlst = []
    for i in ax.patches:
        heightlst.append(i.get_height())
    total = sum(heightlst)
    
    for i in ax.patches:
        x = i.get_x()+0.2
        height = i.get_height()+4.3 
        value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
        
        ax.text(x, height, value, fontsize=14,color='black')

# %% [markdown]
# now percent dir is created for finding the pecententage of each company of cars

# %%
figure, ax = plt.subplots(figsize=(8, 6))
sns.countplot(x="model", data=car, order=car['model'].value_counts().index[:5], palette='ocean', ax=ax)
percent(ax)
ax.set_title('Car Models Distribution', fontsize=14)
ax.set_xlabel('Model', fontsize=12)
ax.set_ylabel('Count', fontsize=12)
ax.tick_params(labelsize=10, axis='both')
plt.tight_layout()
plt.show()

# %% [markdown]
# In the Car dataset, cars with the Maruti model are the most numerous models in the dataset after Hyundai and Mahindra.

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=car, x='year', kde=True, color='green')
plt.title('Distribution of Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This plot shows the distribution of the 'year' column in the 'car' dataset. We can see that the majority of the cars in the dataset are from the years 2010-2020, with a peak in the years 2015-2018. This indicates that the dataset may be biased towards more recent cars.

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=car, x='km_driven', y='selling_price', color='green')
plt.title('Selling Price vs. Km Driven')
plt.xlabel('Km Driven')
plt.ylabel('Selling Price')
plt.show()

# %% [markdown]
# We can observe from the scatter plot that there is a weak negative correlation between selling_price and km_driven, which means that as the km_driven increases, the selling_price tends to decrease. However, this relationship is not very strong and there is a lot of variability in the data.

# %%
plt.figure(figsize=(18, 8))

plt.subplot(2, 2, 1)
sns.boxplot(x='fuel', y='selling_price', data=car, palette='Blues_r')
plt.title('Fuel Type vs Selling Price')

plt.subplot(2, 2, 2)
sns.boxplot(x='transmission', y='selling_price', data=car, palette='Blues_r')
plt.title('Transmission vs Selling Price')

plt.subplot(2, 2, 3)
sns.boxplot(x='owner', y='selling_price', data=car, palette='Blues_r')
plt.title('Owner vs Selling Price')

plt.subplot(2, 2, 4)
sns.boxplot(x='seller_type', y='selling_price', data=car, palette='Blues_r')
plt.title('Seller Type vs Selling Price')

plt.tight_layout()
plt.show()

# %% [markdown]
# The box plot summarizes the distribution of selling_price across different categories. The box represents the interquartile range (IQR), which contains the middle 50% of the data. The line inside the box represents the median, and the whiskers represent the range of the data (excluding outliers).

# %% [markdown]
# From the box plots, we can see that there are some differences in selling price between different categories. For example, cars with diesel fuel type tend to have a higher selling price than those with petrol or CNG fuel type. Similarly, cars with manual transmission tend to have a lower selling price than those with automatic transmission. Cars with fewer owners also tend to have a higher selling price than those with more owners. Finally, cars sold by individuals tend to have a lower selling price than those sold by dealerships.

# %% [markdown]
# # Categorical Summary

# %%
def categorical_summarized(dataframe, x=None, y=None, hue=None, palette='Blues_r', verbose=True, xticks_rotation=0):
    '''
    Helper function that gives a quick summary of a given column of categorical data
    Arguments
    =========
    dataframe: pandas dataframe
    x: str. horizontal axis to plot the labels of categorical data, y would be the count
    y: str. vertical axis to plot the labels of categorical data, x would be the count
    hue: str. if you want to compare it another variable (usually the target variable)
    palette: array-like. Colour of the plot
    xticks_rotation: int. Rotation angle of the x-axis labels
    color: str. Color of the count plot
    Returns
    =======
    Quick Stats of the data and also the count plot
    '''
    if x == None:
        column_interested = y
    else:
        column_interested = x
    series = dataframe[column_interested]
    print(series.describe())
    print('mode: ', series.mode())
    if verbose:
        print('='*80)
        print(series.value_counts())

    ax = sns.countplot(x=x, y=y, hue=hue, data=dataframe, palette=palette)
    plt.xticks(rotation=xticks_rotation)
    plt.show()

# %%
categorical_summarized(car, x='fuel', palette='crest')
# Out:
# count       3577
# unique         5
# top       Diesel
# freq        1800
# Name: fuel, dtype: object
# mode:  0    Diesel
# Name: fuel, dtype: object
# ...
# fuel
# Diesel      1800
# Petrol      1717
# CNG           37
# LPG           22
# Electric       1
# Name: count, dtype: int64

# %%
categorical_summarized(car, x='fuel',palette='crest')
# Out:
# count       3577
# unique         5
# top       Diesel
# freq        1800
# Name: fuel, dtype: object
# mode:  0    Diesel
# Name: fuel, dtype: object
# ...
# fuel
# Diesel      1800
# Petrol      1717
# CNG           37
# LPG           22
# Electric       1
# Name: count, dtype: int64

# %%
categorical_summarized(car, x='seller_type',palette='crest')
# Out:
# count           3577
# unique             3
# top       Individual
# freq            2832
# Name: seller_type, dtype: object
# mode:  0    Individual
# Name: seller_type, dtype: object
# ...
# seller_type
# Individual          2832
# Dealer               712
# Trustmark Dealer      33
# Name: count, dtype: int64

# %%
categorical_summarized(car, x='transmission',palette='crest')
# Out:
# count       3577
# unique         2
# top       Manual
# freq        3265
# Name: transmission, dtype: object
# mode:  0    Manual
# Name: transmission, dtype: object
# ...
# transmission
# Manual       3265
# Automatic     312
# Name: count, dtype: int64

# %%
categorical_summarized(car, x='owner', xticks_rotation=45,palette='crest')
# Out:
# count            3577
# unique              5
# top       First Owner
# freq             2218
# Name: owner, dtype: object
# mode:  0    First Owner
# Name: owner, dtype: object
# ...
# owner
# First Owner             2218
# Second Owner             978
# Third Owner              289
# Fourth & Above Owner      75
# Test Drive Car            17
# Name: count, dtype: int64

# %% [markdown]
# # Summary for above bar plots

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(18, 8))
axs = axs.flatten()

for i, col in enumerate(['fuel', 'transmission', 'owner', 'seller_type']):
    sns.countplot(data=car, x=col, palette=['lightgreen'], ax=axs[i])
    axs[i].set_title(f"{col.title()} Summary", fontsize=18, fontstyle='italic')
    axs[i].set_xlabel('')
    axs[i].tick_params(axis='x', labelrotation=45)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,6))

plt.title('Correlation Matrix', fontsize=18)

# select the columns of interest
columns_of_interest = ["year", "selling_price", "km_driven"]

# create a new dataframe with just the selected columns
car_selected_df = car[columns_of_interest]

# calculate the correlation matrix
corr_matrix = car_selected_df.corr()
sns.heatmap(corr_matrix, cbar=True, annot=True, cmap='Blues')
# Out:
# <Axes: title={'center': 'Correlation Matrix'}>

# %% [markdown]
# From the correlation matrix, we can see that there is a positive correlation between "year" and "selling_price", which indicates that newer cars tend to have higher selling prices. There is also a negative correlation between "km_driven" and "selling_price", which indicates that cars with higher km_driven tend to have lower selling prices. Additionally, we can see that there is a weak negative correlation between "year" and "km_driven", which suggests that newer cars tend to have lower mileage.

# %%
plt.figure(figsize=(8,6))
plt.title('year by km_driven Distribution', fontsize=18)
sns.histplot(data=car, x='year', y='km_driven', bins=100)
#plt.ticklabel_format(style='plain', axis='x')
# Out:
# <Axes: title={'center': 'year by km_driven Distribution'}, xlabel='year', ylabel='km_driven'>

# %% [markdown]
# most cars are still under 100,000 KM and the best car choices are in cars with years between 2007-2019 because the number of KM tends to be small and the number of units is large.

# %% [markdown]
# # Finding the cars which are sold at Max. or Min. price

# %%
pd.pivot_table(data=car, index=['name'], values=['selling_price','km_driven','year']).sort_values(by='selling_price', ascending=False)
# Out:
#                                                    km_driven  selling_price
# name
# Audi RS7 2015-2019 Sportback Performance             13000.0      8900000.0  \
# Mercedes-Benz S-Class S 350d Connoisseurs Edition     6500.0      8150000.0
# Mercedes-Benz GLS 2016-2020 350d 4MATIC              77350.0      5500000.0
# BMW X5 xDrive 30d xLine                              30000.0      4950000.0
# Audi A5 Sportback                                     1500.0      4700000.0
# ...                                                      ...            ...
# Tata Nano Std BSII                                   50000.0        35000.0
# OpelCorsa 1.4 GL                                    100000.0        35000.0
# Maruti 800 EX                                        45000.0        35000.0
# Ford Ikon 1.4 ZXi                                    42743.0        22000.0
# Ford Ikon 1.6 ZXI NXt                                25000.0        20000.0
#
# ...

# %%
pd.pivot_table(data=car, index=['name'], values=['selling_price','km_driven','year']).sort_values(by='km_driven', ascending=False)
# Out:
#                                                km_driven  selling_price
# name
# Chevrolet Tavera Neo LS B3 - 7(C) seats BSIII   350000.0       280000.0  \
# Maruti SX4 S Cross DDiS 320 Delta               320000.0       495000.0
# Volkswagen Jetta 2.0 TDI Comfortline            312000.0       350000.0
# Mahindra Xylo E9                                295000.0       300000.0
# Toyota Innova 2.5 G (Diesel) 7 Seater BS IV     281500.0       550000.0
# ...                                                  ...            ...
# Renault KWID Climber 1.0 MT Opt BSIV              1000.0       541000.0
# Honda Amaze S Petrol BSIV                         1000.0       614000.0
# Ford Ecosport Sports Petrol                       1000.0      1100000.0
# Tata Harrier XE                                   1000.0       426000.0
# Ford Figo Titanium                                 606.0       690500.0
#
#                                                  year
# name
# ...

# %%
pd.pivot_table(data=car, index=['name'], values=['selling_price','km_driven','year']).sort_values(by='year', ascending=False)
# Out:
#                                    km_driven  selling_price    year
# name
# Ford Freestyle Titanium Plus          1010.0       852000.0  2020.0
# Mahindra Scorpio S5 BSIV             11000.0      1200000.0  2020.0
# Honda Amaze S Petrol BSIV             1000.0       614000.0  2020.0
# Hyundai Grand i10 Nios Sportz         5000.0       600000.0  2020.0
# Hyundai Elite i20 Magna Plus BSIV     7300.0       545000.0  2020.0
# ...                                      ...            ...     ...
# Maruti Omni 5 Str STD                60000.0        65000.0  1998.0
# Mercedes-Benz E-Class 230            35000.0      1000000.0  1998.0
# Maruti Esteem AX                     70000.0        79000.0  1997.0
# Mahindra Jeep CL 500 MDI             77500.0       200000.0  1996.5
# Maruti Gypsy E MG410W ST            100000.0        95000.0  1995.0
#
# [1491 rows x 3 columns]

# %% [markdown]
# From above 3 Table we get these conclussions;
#
# - The Audi RS7 2015-2019 Sportback Performance is the car model with the highest selling price, reaching 8,900,000 with a relatively small number of KM.
# - In contrast, the Ford Icon 1.6 ZXI NXt is a car model with the lowest selling price of 20,000 but has a fairly high KM Driven, reaching 25,000 KM because it was purchased in 2005.
#
# - Chevrolet Tavera Neo LS B3 - 7(C) seats BSIII is the car model with the highest KM Driven, reaching 350,000 KM with a selling price of 280,000 purchased in 2010.
# - On the other hand, the Ford Figo Titanium is the car model with the lowest KM Driven with 606 KM with a selling price of 690,500 purchased in 2020.

# %%
plt.figure(figsize=(8,8))

plt.subplot(2,2,1)
plt.title('Fuel by selling_price Distribution', fontsize=18)
sns.boxplot(data=car, x='selling_price', y='fuel', palette='Set2')
plt.ticklabel_format(style='plain', axis='x')
plt.subplot(2,2,2)
plt.title('Transmission by selling_price Distribution', fontsize=18)
sns.boxplot(data=car, x='selling_price', y='transmission', palette='Set2')
plt.ticklabel_format(style='plain', axis='x')
plt.subplot(2,2,3)
plt.title('Owner by selling_price Distribution', fontsize=18)
sns.boxplot(data=car, x='selling_price', y='owner', palette='Set2')
plt.ticklabel_format(style='plain', axis='x')
plt.subplot(2,2,4)
plt.title('Seller_type by selling_price Distribution', fontsize=18)
sns.boxplot(data=car, x='selling_price', y='seller_type', palette='Set2')
plt.ticklabel_format(style='plain', axis='x')

# %% [markdown]
# # Factors Affecting Selling Price :

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(24,16))

sns.boxplot(ax=axs[0,0], data=car, x='selling_price', y='fuel', palette='Set2')
axs[0,0].set_title('Fuel by selling_price Distribution', fontsize=18)
axs[0,0].ticklabel_format(style='plain', axis='x')
axs[0,0].set_xlabel('Selling Price', fontsize=14)
axs[0,0].set_ylabel('Fuel', fontsize=14)

sns.boxplot(ax=axs[0,1], data=car, x='selling_price', y='transmission', palette='Set2')
axs[0,1].set_title('Transmission by selling_price Distribution', fontsize=18)
axs[0,1].ticklabel_format(style='plain', axis='x')
axs[0,1].set_xlabel('Selling Price', fontsize=14)
axs[0,1].set_ylabel('Transmission', fontsize=14)

sns.boxplot(ax=axs[1,0], data=car, x='selling_price', y='owner', palette='Set2')
axs[1,0].set_title('Owner by selling_price Distribution', fontsize=18)
axs[1,0].ticklabel_format(style='plain', axis='x')
axs[1,0].set_xlabel('Selling Price', fontsize=14)
axs[1,0].set_ylabel('Owner', fontsize=14)

sns.boxplot(ax=axs[1,1], data=car, x='selling_price', y='seller_type', palette='Set2')
axs[1,1].set_title('Seller_type by selling_price Distribution', fontsize=18)
axs[1,1].ticklabel_format(style='plain', axis='x')
axs[1,1].set_xlabel('Selling Price', fontsize=14)
axs[1,1].set_ylabel('Seller Type', fontsize=14)

plt.tight_layout()

# %% [markdown]
# Findings:
#
# - In this Car  dataset, Cars with the Diesel Fuel type have more influence on Selling Prices.
# - The Transmission Automatic type which has more influence on Selling prices than Manual.
# - First Owner also has a high influence on Selling Prices.
# - Seller Type Dealer also has a high influence on Selling Price.

# %% [markdown]
# # CONCLUSION :

# %% [markdown]
# 1. The Maruti model car has higher units in the Car dataset after Hyundai and Mahindra.
# 2. The amount of the car will be high as compared to other if the car has these properties>> Fuel type- Diesel, Transmission Type-    Manual Transmissions, Owner Type- First Owner Cars, and Seller- Individual Sellers.
# 3. IF there is a new car, the selling price will be high, and the KM Driven will be low.
